# %% [markdown]
# <a href="https://colab.research.google.com/github/wiwi1510/DA_Python/blob/main/Analyze_Times_World_University_Rankings_Team_2_Python_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **I. About Data**

# %% [markdown]
# **The dataset was obtained by scraping the Times World University Rankings website with Python**
# *Feature Description*
# The dataset has a total of 14 columns.
#
# 1. World_Rank:              rank given to the university
# 2. University_Name:         name of the university
# 3. Country:                 country in which the university is located
# 4. Teaching_Rating:         the learning environment
# 5. Inter_Outlook_Rating: proportion of international students and staffs
# 6. Research_Rating: quality of research at the university
# 7. Citations_Rating: research influence
# 8. Industry_Income_Rating: knowledge transfer
# 9. Total_Score: score of the university based on the five key metrics mentioned above
# 10. Num_Students: total number of students
# 11. Student/Staff_Ratio: staff to student ratio
# 12. %_Inter_Students: number of international students enrolled at the university
# 13. %_Female_Students: number of female students enrolled at the university
# 14. Year: year of ranking

# %% [markdown]
# ## ***I.1.How to calculate total score of university with 5 metrics***

# %% [markdown]
# 1. Teaching (the learning environment): 30%  (teaching_rating)
#
#
#     -Reputation survey: 15%
#     -Staff-to-student ratio: 4.5%
#     -Doctorate-to-bachelor’s ratio: 2.25%
#     -Doctorates-awarded-to-academic-staff ratio: 6%
#     -Institutional income: 2.25%
#
# 2. International outlook (staff, students, research): 7.5% (inter_outlook_rating)
#
#
#     -Proportion of international students: 2.5%
#     -Proportion of international staff: 2.5%
#     -International collaboration: 2.5%
#
# 3. Research (volume, income and reputation): 30%  (research_rating)
#
#
#     -Reputation survey: 18%
#     -Research income: 6%
#     -Research productivity: 6%
#
# 4. Citations (research influence): 30% (citations_rating)
#
# 5. Industry income (knowledge transfer): 2.5%  (industry_income_rating)

# %% [markdown]
# ## ***I.2.Import Libraries and the original data type***

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
FILE_URL = '/content/drive/MyDrive/DATA/colab my/Times World University Rankings (2011-2016).xlsx'
FILE_URL_SUB = '/content/drive/MyDrive/DATA/colab my/region_country.xlsx'

# %% [markdown]
# ### Main Data

# %%
uni = pd.read_excel(FILE_URL)
uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2603 entries, 0 to 2602
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   World_Rank              2603 non-null   object
#  1   University_Name         2603 non-null   object
#  2   Country                 2603 non-null   object
#  3   Teaching_Rating         2603 non-null   float64
#  4   Inter_Outlook_Rating    2603 non-null   object
#  5   Research_Rating         2603 non-null   float64
#  6   Citations_Rating        2603 non-null   float64
#  7   Industry_Income_Rating  2603 non-null   object
#  8   Total_Score             2603 non-null   object
#  9   Num_Students            2544 non-null   float64
#  10  Student/Staff_Ratio     2544 non-null   float64
#  11  %_Inter_Students        2536 non-null   float64
#  12  %_Female_Students       2370 non-null   object
#  13  Year                    2603 non-null   int64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 284.8+ KB

# %% [markdown]
# We can see from the dataset info() method that there are many null values across multiple columns with NaN and hyphen mark. Also, the 5 metrics columns to calculate the Total score column are **object** type.
#
# Let's take a look at the number of null values.

# %%
uni.head()
# Out:
#   World_Rank                        University_Name                   Country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    Teaching_Rating Inter_Outlook_Rating  Research_Rating  Citations_Rating  \
# 0             99.7                 72.4             98.7              98.8
# 1             97.7                 54.6             98.0              99.9
# 2             97.8                 82.3             91.4              99.9
# 3             98.3                 29.5             98.1              99.2
# 4             90.9                 70.3             95.4              99.9
#
#   Industry_Income_Rating Total_Score  Num_Students  Student/Staff_Ratio  \
# 0                   34.5        96.1       20152.0                  8.9
# 1                   83.7          96        2243.0                  6.9
# 2                   87.5        95.6       11074.0                  9.0
# 3                   64.3        94.3       15596.0                  7.8
# 4                      -        94.2        7929.0                  8.4
#
#    %_Inter_Students %_Female_Students  Year
# 0              25.0               NaN  2011
# 1              27.0                33  2011
# 2              33.0                37  2011
# 3              22.0                42  2011
# 4              27.0                45  2011

# %%
uni.tail()
# Out:
#      World_Rank                University_Name      Country  Teaching_Rating  \
# 2598    601-800            Yeungnam University  South Korea             18.6
# 2599    601-800  YÄ±ldÄ±z Technical University       Turkey             14.5
# 2600    601-800       Yokohama City University        Japan             24.0
# 2601    601-800   Yokohama National University        Japan             20.1
# 2602    601-800             Yuan Ze University       Taiwan             16.2
#
#      Inter_Outlook_Rating  Research_Rating  Citations_Rating  \
# 2598                 24.3             10.9              26.5
# 2599                 14.9              7.6              19.3
# 2600                 16.1             10.2              36.4
# 2601                 23.3             16.0              13.5
# 2602                 17.7             18.3              28.6
#
#      Industry_Income_Rating Total_Score  Num_Students  Student/Staff_Ratio  \
# 2598                   35.4           -       21958.0                 15.3
# 2599                     44           -       31268.0                 28.7
# 2600                   37.9           -        4122.0                  3.7
# 2601                   40.4           -       10117.0                 12.1
# 2602                   39.8           -        8663.0                 20.6
#
#       %_Inter_Students %_Female_Students  Year
# 2598               3.0                48  2016
# 2599               2.0                36  2016
# 2600               3.0               NaN  2016
# 2601               8.0                28  2016
# 2602               4.0                43  2016

# %% [markdown]
# ### Sub-Data
# This data is just for supporting analyzing the main data in Visualization part.

# %%
region_dict = pd.read_excel(FILE_URL_SUB)
region_dict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Region   32 non-null     object
#  1   Country  32 non-null     object
# dtypes: object(2)
# memory usage: 640.0+ bytes

# %% [markdown]
# # **II. Data Cleaning and processing**

# %% [markdown]
# There are 2 things had to convert.

# %% [markdown]
# ## ***II.1.Convert some columns/data to a correct data type***

# %% [markdown]
# ### Main DataFrame

# %%
def clean_col(col):
    col = col.strip()
    col = col.replace("Student/Staff", "Student_Staff")
    col = col.lower()
    return col

new_columns = []
for c in uni.columns:
    clean_c = clean_col(c)
    new_columns.append(clean_c)
uni.columns = new_columns

#replace '-' to null
uni = uni.replace('-','NaN')

# change columns type
uni['inter_outlook_rating'] = uni['inter_outlook_rating'].astype(float)
uni['industry_income_rating'] = uni['industry_income_rating'].astype(float)
uni['total_score'] = uni['total_score'].astype(float)
uni['%_female_students'] = uni['%_female_students'].astype(float)

uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2603 entries, 0 to 2602
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   world_rank              2603 non-null   object
#  1   university_name         2603 non-null   object
#  2   country                 2603 non-null   object
#  3   teaching_rating         2603 non-null   float64
#  4   inter_outlook_rating    2594 non-null   float64
#  5   research_rating         2603 non-null   float64
#  6   citations_rating        2603 non-null   float64
#  7   industry_income_rating  2385 non-null   float64
#  8   total_score             1201 non-null   float64
#  9   num_students            2544 non-null   float64
#  10  student_staff_ratio     2544 non-null   float64
#  11  %_inter_students        2536 non-null   float64
#  12  %_female_students       2367 non-null   float64
#  13  year                    2603 non-null   int64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 284.8+ KB

# %% [markdown]
# ### Sub Data

# %%
def clean_col_sub(col):
    col = col.strip()
    col = col.lower()
    return col

new_columns_sub = []
for d in region_dict.columns:
    clean_d = clean_col_sub(d)
    new_columns_sub.append(clean_d)
region_dict.columns = new_columns_sub

region_dict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   region   32 non-null     object
#  1   country  32 non-null     object
# dtypes: object(2)
# memory usage: 640.0+ bytes

# %% [markdown]
# ## ***II.2.Convert NaN value in Total_Score column with a correct syntax***

# %% [markdown]
# As we can see in the original dataframe, there is a lot of null data in the total score column although there is still enough data in the calculated metrics.
# So we will recalculate it for further analysis.
#
#
# The Total Score is calculated by 5 metrics, which are teaching_rating,inter_outlook_rating, research_rating, citations_rating, industry_income_rating
#
# **Note:**
#
# - When there is a nan value in a certain column of row, don't caculated it.
#
# - Only apply the syntax to a nan value in total score column and round it with 1 decimal

# %% [markdown]
# ####The current data in 5 metrics columns

# %%
#@title Default title text
uni.loc[:,['teaching_rating','inter_outlook_rating', 'research_rating', 'citations_rating', 'industry_income_rating', 'total_score']]
# Out:
#       teaching_rating  inter_outlook_rating  research_rating  \
# 0                99.7                  72.4             98.7
# 1                97.7                  54.6             98.0
# 2                97.8                  82.3             91.4
# 3                98.3                  29.5             98.1
# 4                90.9                  70.3             95.4
# ...               ...                   ...              ...
# 2598             18.6                  24.3             10.9
# 2599             14.5                  14.9              7.6
# 2600             24.0                  16.1             10.2
# 2601             20.1                  23.3             16.0
# 2602             16.2                  17.7             18.3
#
#       citations_rating  industry_income_rating  total_score
# 0                 98.8                    34.5         96.1
# 1                 99.9                    83.7         96.0
# 2                 99.9                    87.5         95.6
# 3                 99.2                    64.3         94.3
# 4                 99.9                     NaN         94.2
# ...                ...                     ...          ...
# 2598              26.5                    35.4          NaN
# 2599              19.3                    44.0          NaN
# 2600              36.4                    37.9          NaN
# 2601              13.5                    40.4          NaN
# 2602              28.6                    39.8          NaN
#
# [2603 rows x 6 columns]

# %% [markdown]
# ####Check how many null data in the calculated columns

# %% [markdown]
# There are 1402 null values in Total Score column, which is more than the other metrics columns

# %%
uni.isna().sum()
# Out:
# world_rank                   0
# university_name              0
# country                      0
# teaching_rating              0
# inter_outlook_rating         9
# research_rating              0
# citations_rating             0
# industry_income_rating     218
# total_score               1402
# num_students                59
# student_staff_ratio         59
# %_inter_students            67
# %_female_students          236
# year                         0
# dtype: int64

# %% [markdown]
# ###Apply syntax

# %% [markdown]
# Extract 5 metrics columns and total score to make it a smaller dataframe for easier to apply the syntax

# %%
df = pd.DataFrame(uni, columns=['teaching_rating','inter_outlook_rating', 'research_rating', 'citations_rating', 'industry_income_rating', 'total_score'])
df.isna().sum()
# Out:
# teaching_rating              0
# inter_outlook_rating         9
# research_rating              0
# citations_rating             0
# industry_income_rating     218
# total_score               1402
# dtype: int64

# %%
#Write a syntax
nan_to_totalscore = []
for index, row in df.iterrows(): # return the result list of that row, iterrow(index: the number of rows, row:data of that row)
  if not np.isnan(row['total_score']): # Check value is not NaN
    nan_to_totalscore.append(row['total_score']) # Keep not NaN value
    continue
  # Calculate new value for NaN value
  new_value = (row['teaching_rating']*(float(30)/100))+(row['inter_outlook_rating']*(float(7.5)/100))+(row['citations_rating']*(float(30)/100))+(row['research_rating']*(float(30)/100))+(row['industry_income_rating']*(float(2.5)/100))
  nan_to_totalscore.append(new_value.round(1))
print(nan_to_totalscore)
# Out:
# [96.1, 96.0, 95.6, 94.3, 94.2, 91.2, 91.2, 91.1, 90.6, 89.5, 87.7, 86.9, 86.4, 83.9, 83.4, 83.4, 82.0, 81.0, 79.5, 79.3, 79.2, 78.4, 78.0, 76.5, 75.9, 75.6, 75.3, 75.1, 75.0, 73.8, 73.8, 73.2, 73.0, 72.9, 71.7, 71.0, 70.7, 69.9, 69.5, 69.2, 69.0, 68.6, 67.0, 67.0, 67.0, 67.0, 66.9, 66.5, 66.0, 66.0, 65.9, 65.6, 65.2, 65.0, 64.9, 64.7, 64.6, 64.2, 64.0, 63.9, 63.0, 63.0, 62.8, 62.7, 62.2, 62.1, 61.6, 61.4, 61.4, 61.4, 61.2, 61.1, 60.7, 60.7, 60.4, 60.3, 59.7, 59.6, 59.5, 59.5, 59.1, 59.1, 59.0, 59.0, 58.9, 58.3, 58.0, 57.9, 57.8, 57.7, 57.7, 57.7, 57.6, 57.5, 57.3, 57.3, 57.3, 57.2, 57.1, 57.0, 56.9, 56.6, 56.5, 56.4, 56.3, 56.2, 56.1, 56.1, 56.0, 56.0, 55.6, 55.4, 55.4, 55.3, 55.2, 55.2, 55.1, 55.0, 54.8, 54.6, 54.6, 54.5, 54.5, 54.4, 54.4, 54.4, 54.3, 54.2, 54.0, 53.4, 53.4, 53.3, 53.3, 53.3, 52.7, 52.6, 52.5, 52.4, 52.3, 52.2, 52.2, 52.1, 52.0, 51.9, 51.8, 51.8, 51.6, 51.6, 51.4, 51.4, 51.3, 51.2, 51.2, 51.2, 51.1, 51.0, 51.0, 50.7, 50.4, 50.4, 50.3, 50.3, 50.2, 50.1, 50.0, 50.0, 49.9, 49.8, 49.8, 49.7, 49.6, 49.4, 49.3, 49.0, 49.0, 49.0, 48.8, 48.5, 48.5, 48.5, 48.3, 48.2, 47.7, 47.6, 47.5, 47.3, 47.2, 47.2, 47.0, 46.9, 46.9, 46.9, 46.8, 46.8, 46.7, 46.5, 46.4, 46.4, 46.2, 46.2, 94.8, 93.9, 93.9, 93.6, 92.9, 92.4, 92.3, 90.7, 90.2, 89.8, 89.1, 87.5, 87.3, 85.8, 85.0, 84.9, 83.2, 82.8, 81.6, 80.5, 78.4, 77.4, 77.4, 77.0, 76.5, 76.2, 75.8, 75.5, 74.9, 74.3, 74.2, 73.1, 73.0, 72.3, 72.1, 72.0, 71.9, 71.2, 71.2, 70.9, 70.5, 70.0, 69.3, 69.0, 67.6, 66.3, 66.0, 65.7, 65.6, 65.6, 64.9, 64.8, 64.6, 64.2, 64.0, 63.2, 63.0, 62.4, 62.0, 62.0, 61.9, 61.7, 61.5, 61.1, 61.0, 60.9, 60.8, 60.4, 60.3, 59.6, 59.5, 59.0, 58.7, 58.6, 57.4, 57.4, 57.3, 57.3, 57.0, 56.9, 56.8, 56.8, 56.4, 56.0, 55.7, 55.4, 55.2, 55.1, 55.0, 54.9, 54.8, 54.7, 54.6, 54.5, 54.5, 54.4, 54.2, 54.0, 53.9, 53.7, 53.6, 53.4, 53.2, 53.1, 53.1, 53.0, 52.9, 52.8, 52.6, 52.5, 52.2, 52.1, 51.9, 51.4, 51.3, 51.2, 51.1, 51.1, 51.0, 50.8, 50.4, 50.4, 50.2, 50.1, 50.0, 50.0, 49.9, 49.9, 49.9, 49.8, 49.7, 49.7, 49.5, 49.2, 49.0, 49.0, 49.0, 48.0, 47.9, 47.7, 47.6, 47.6, 47.5, 47.4, 47.3, 47.0, 47.0, 46.9, 46.8, 46.7, 46.6, 46.6, 46.6, 46.2, 46.2, 46.1, 46.0, 46.0, 45.9, 45.9, 45.9, 45.8, 45.8, 45.7, 45.7, 45.4, 45.2, 45.1, 45.0, 45.0, 45.0, 44.8, 44.6, 44.6, 44.6, 44.5, 44.2, 44.1, 44.1, 43.8, 43.6, 43.6, 43.6, 43.4, 43.2, 43.1, 43.0, 43.0, 42.9, 42.9, 42.8, 42.7, 42.6, 42.5, 42.4, 41.6, 41.5, 41.5, 41.5, 41.4, 40.2, 37.7, 40.4, 38.7, 41.0, 40.6, 39.4, 39.8, nan, 37.4, 37.4, 41.3, 40.2, 39.6, 39.2, 38.8, 38.4, 40.3, 38.4, 38.7, 37.5, 37.3, 40.4, 39.2, 38.7, 37.7, 38.2, nan, 36.8, nan, 35.4, 36.4, 36.1, 37.2, 35.8, 35.3, 36.1, 36.0, 37.3, 36.0, 36.1, 35.5, 36.6, 36.9, 37.3, 37.3, 35.6, 35.3, 36.1, 36.5, 34.8, 33.4, 34.3, 33.4, 33.8, 33.6, 35.2, 33.4, 34.2, 34.7, 34.7, 33.4, 34.8, 34.0, 33.5, 33.6, nan, 35.1, 34.3, 34.8, 35.1, 34.3, 34.0, 34.1, 34.8, nan, 33.2, 33.1, 32.5, 32.3, 31.6, 31.9, 33.1, 33.2, 32.3, 32.7, 32.0, 31.3, 33.0, 33.1, 33.1, 31.7, 32.0, 33.3, 31.3, nan, 32.7, 31.7, 32.3, 33.0, 32.0, 26.4, 31.0, 28.6, 27.0, 28.6, 30.6, 30.8, 30.8, 29.3, 31.2, 28.9, 28.2, 26.5, 29.1, 27.9, 28.8, 26.5, 29.7, 26.9, 29.0, 30.1, 26.5, 30.7, 27.5, 26.6, 28.0, 30.4, 30.4, 29.0, 28.0, 27.1, 30.4, 30.7, 27.6, 27.0, 26.8, 29.1, 26.4, 30.1, 30.6, 28.3, 30.9, 26.9, 30.6, 29.6, nan, 26.5, 29.7, 29.2, 29.9, 21.3, 21.7, 21.9, 25.1, 23.1, 22.7, 25.3, 22.4, 22.8, 24.2, 21.6, 23.2, 22.6, 22.8, 21.7, 24.6, 25.6, 24.8, 23.8, nan, 21.4, 25.6, 21.7, 24.7, 25.4, 21.4, 21.7, nan, 21.9, 22.3, 25.1, 23.2, 21.6, 23.9, 24.6, 21.6, 25.7, 22.8, 23.6, 22.8, 24.5, 25.5, 25.7, 24.0, 24.8, 25.2, 25.2, 21.9, 24.4, 24.1, 25.3, 95.5, 93.7, 93.7, 93.6, 93.1, 92.7, 92.6, 90.6, 90.5, 90.4, 89.2, 87.8, 87.7, 87.0, 86.6, 85.6, 85.5, 83.3, 83.1, 82.6, 82.2, 81.5, 81.2, 79.9, 78.8, 78.8, 78.3, 77.9, 77.5, 77.3, 76.9, 76.1, 75.8, 75.7, 75.6, 75.6, 75.4, 75.2, 73.1, 73.0, 72.8, 72.4, 72.4, 71.8, 71.8, 70.7, 70.5, 70.4, 70.1, 69.4, 68.9, 67.1, 67.0, 66.8, 66.8, 66.3, 66.2, 66.1, 65.9, 65.9, 65.8, 65.7, 65.7, 65.1, 64.4, 64.4,  ...

# %%
#apply to dataframe uni
uni['total_score'] = nan_to_totalscore
uni
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800          YÄ±ldÄ±z Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching_rating  inter_outlook_rating  \
# 0     United States of America             99.7                  72.4
# 1     United States of America             97.7                  54.6
# 2     United States of America             97.8                  82.3
# 3     United States of America             98.3                  29.5
# 4     United States of America             90.9                  70.3
# ...                        ...              ...                   ...
# 2598               South Korea             18.6                  24.3
# 2599                    Turkey             14.5                  14.9
# 2600                     Japan             24.0                  16.1
# 2601                     Japan             20.1                  23.3
# 2602                    Taiwan             16.2                  17.7
#
#       research_rating  citations_rating  industry_income_rating  total_score  \
# 0                98.7              98.8                    34.5         96.1
# 1                98.0              99.9                    83.7         96.0
# 2                91.4              99.9                    87.5         95.6
# 3                98.1              99.2                    64.3         94.3
# 4                95.4              99.9                     NaN         94.2
# ...               ...               ...                     ...          ...
# 2598             10.9              26.5                    35.4         19.5
# 2599              7.6              19.3                    44.0         14.6
# 2600             10.2              36.4                    37.9         23.3
# 2601             16.0              13.5                    40.4         17.6
# 2602             18.3              28.6                    39.8         21.3
#
#       num_students  student_staff_ratio  %_inter_students  %_female_students  \
# 0          20152.0                  8.9              25.0                NaN
# 1           2243.0                  6.9              27.0               33.0
# 2          11074.0                  9.0              33.0               37.0
# 3          15596.0                  7.8              22.0               42.0
# 4           7929.0                  8.4              27.0               45.0
# ...            ...                  ...               ...                ...
# 2598       21958.0                 15.3               3.0               48.0
# 2599       31268.0                 28.7               2.0               36.0
# 2600        4122.0                  3.7               3.0                NaN
# 2601       10117.0                 12.1               8.0               28.0
# 2602        8663.0                 20.6               4.0               43.0
#
#       year
# 0     2011
# 1     2011
# 2     2011
# 3     2011
# 4     2011
# ...    ...
# 2598  2016
# 2599  2016
# 2600  2016
# 2601  2016
# 2602  2016
#
# [2603 rows x 14 columns]

# %% [markdown]
# ###Check whether the total score column still has null data

# %%
uni.isna().sum()
# Out:
# world_rank                  0
# university_name             0
# country                     0
# teaching_rating             0
# inter_outlook_rating        9
# research_rating             0
# citations_rating            0
# industry_income_rating    218
# total_score                78
# num_students               59
# student_staff_ratio        59
# %_inter_students           67
# %_female_students         236
# year                        0
# dtype: int64

# %%
#get the 78 null data of total_score
uni[uni['total_score'].isna()]
# Out:
#      world_rank                    university_name                   country  \
# 408     201-225                  Tulane University  United States of America
# 427     226-250                Carleton University                    Canada
# 429     226-250          Colorado State University  United States of America
# 466     251-275  University of Hawaiâi at MÄnoa  United States of America
# 475     251-275             Wayne State University  United States of America
# ...         ...                                ...                       ...
# 2566    601-800              Suez Canal University                     Egypt
# 2573    601-800               University of Tehran                      Iran
# 2574    601-800     University of Texas at El Paso  United States of America
# 2575    601-800              Texas Tech University  United States of America
# 2595    601-800      West University of TimiÅoara                   Romania
#
#       teaching_rating  inter_outlook_rating  research_rating  \
# 408              28.0                  29.8             34.1
# 427              17.0                  58.6             24.2
# 429              26.9                  25.5             32.0
# 466              31.3                  34.6             29.2
# 475              34.7                  24.6             16.4
# ...               ...                   ...              ...
# 2566             22.6                  31.6              5.9
# 2573             26.1                  16.5             16.9
# 2574             18.6                  30.4             18.7
# 2575             27.9                  36.8             17.2
# 2595             16.1                  21.0              3.9
#
#       citations_rating  industry_income_rating  total_score  num_students  \
# 408               58.8                     NaN          NaN       11381.0
# 427               61.6                     NaN          NaN       25036.0
# 429               51.2                     NaN          NaN       26769.0
# 466               44.3                     NaN          NaN           NaN
# 475               55.2                     NaN          NaN       23065.0
# ...                ...                     ...          ...           ...
# 2566              16.0                     NaN          NaN       16817.0
# 2573              15.8                     NaN          NaN       53802.0
# 2574              18.4                     NaN          NaN       19123.0
# 2575              22.0                     NaN          NaN       29512.0
# 2595              22.4                     NaN          NaN       12933.0
#
#       student_staff_ratio  %_inter_students  %_female_students  year
# 408                   8.4               8.0               56.0  2012
# 427                  29.8              18.0               47.0  2012
# 429                  19.0               5.0               52.0  2012
# 466                   NaN               NaN                NaN  2012
# 475                  10.7               7.0               57.0  2012
# ...                   ...               ...                ...   ...
# 2566                  6.0               NaN               65.0  2016
# 2573                 27.0               1.0               45.0  2016
# 2574                 29.0               7.0               54.0  2016
# 2575                 20.9               7.0               46.0  2016
# 2595                 19.0               3.0               62.0  2016
#
# [78 rows x 14 columns]

# %% [markdown]
# # **III. Explore data**

# %% [markdown]
# Let's explore 3 things in here

# %% [markdown]
# ##***III.1.The top 5 Countries has in the list during the selected period (2011-2016)***

# %%
country_counts = uni['country'].value_counts()
print(country_counts)
# Out:
# United States of America     659
# United Kingdom               300
# Germany                      152
# Australia                    117
# Canada                       108
#                             ...
# Unted Kingdom                  1
# Cyprus                         1
# Unisted States of America      1
# Luxembourg                     1
# Lithuania                      1
# Name: country, Length: 72, dtype: int64

# %% [markdown]
# ## ***III.2.Checking the top 5 universities in each year***

# %%
uni2011= uni[uni['year']==2011]
uni2012= uni[uni['year']==2012]
uni2013= uni[uni['year']==2013]
uni2014= uni[uni['year']==2014]
uni2015= uni[uni['year']==2015]
uni2016= uni[uni['year']==2016]

top5_2011 = uni2011.loc[:,['university_name','world_rank','total_score','year']].head(5)
top5_2012 = uni2012.loc[:,['university_name','world_rank','total_score','year']].head(5)
top5_2013 = uni2013.loc[:,['university_name','world_rank','total_score','year']].head(5)
top5_2014 = uni2014.loc[:,['university_name','world_rank','total_score','year']].head(5)
top5_2015 = uni2015.loc[:,['university_name','world_rank','total_score','year']].head(5)
top5_2016 = uni2016.loc[:,['university_name','world_rank','total_score','year']].head(5)

print(top5_2011,top5_2012,top5_2013,top5_2014,top5_2015,top5_2016)
# Out:
#                          university_name world_rank  total_score  year
# 0                     Harvard University          1         96.1  2011
# 1     California Institute of Technology          2         96.0  2011
# 2  Massachusetts Institute of Technology          3         95.6  2011
# 3                    Stanford University          4         94.3  2011
# 4                   Princeton University          5         94.2  2011                         university_name world_rank  total_score  year
# 200  California Institute of Technology          1         94.8  2012
# 201                  Harvard University          2         93.9  2012
# 202                 Stanford University          2         93.9  2012
# 203                University of Oxford          4         93.6  2012
# 204                Princeton University          5         92.9  2012                            university_name world_rank  total_score  year
# 602     California Institute of Technology          1         95.5  2013
# 603                    Stanford University          2         93.7  2013
# 604                   University of Oxford          2         93.7  2013
# 605                     Harvard University          4         93.6  2013
# 606  Massachusetts Institute of Technology          5         93.1  2013                             university_name world_rank  total_score  year
# 1002     California Institute of Technology          1         94.9  2014
# 1003                     Harvard University          2         93.9  2014
# 1004                   University of Oxford          2         93.9  2014
# 1005                    Stanford University          4         93.8  2014
# 1006  Massachusetts Institute of Technology          5         93.0  2014                          university_name world_rank  total_score  year
# 1402  California Institute of Technology          1         94.3  2015
# 1403                  Harvard University          2         93.3  2015
# 1404                University of Oxford          3         93.2  2015
# 1405                 Stanford University          4         92.9  2015
# 1406             University of Cambridge          5         92.0  2015                             university_name world_rank  total_score  year
# 1803     California Institute of Technology          1         95.2  2016
# 1804                   University of Oxford          2         94.2  2016
# 1805                    Stanford University          3         93.9  2016
# 1806                University of Cambridge          4         92.8  2016
# 1807  Massachusetts Institute of Technology          5         92.0  2016

# %% [markdown]
# ##***III.3.Pick a University and check how it has been ranked all the time.***

# %%
def rank_change(uni):
    
    yr1 = 2011
    yr2 = 2012
    yr3 = 2013
    yr4 = 2014
    yr5 = 2015
    yr6 = 2016
    
    # Get values corresponding to min and max years in case
   
    rank_yr1 = uni[uni['year']==yr1]['world_rank']
    rank_yr2 = uni[uni['year']==yr2]['world_rank']
    rank_yr3 = uni[uni['year']==yr3]['world_rank']
    rank_yr4 = uni[uni['year']==yr4]['world_rank']
    rank_yr5 = uni[uni['year']==yr5]['world_rank']
    rank_yr6 = uni[uni['year']==yr6]['world_rank']

    return rank_yr1,rank_yr2,rank_yr3,rank_yr4,rank_yr5,rank_yr6

# %%
uni_wanted = pd.DataFrame(uni, columns=['university_name', 'total_score','world_rank','year'])
uni_wanted_group = uni_wanted.groupby('university_name').apply(rank_change)

#Enter a wanted university name
enter_uni_name = uni_wanted_group.loc[['Australian National University','University of Cambridge']]
print(enter_uni_name)
# Out:
# university_name
# Australian National University    ([43], [38], [37], [48], [45], [52])
# University of Cambridge                 ([6], [6], [7], [7], [5], [4])
# dtype: object

# %% [markdown]
# # **IV. Visualizing universities by year and type**

# %% [markdown]
# Having 9 small parts

# %% [markdown]
# ## ***IV.1.Cover the World rank column from Object to Interger type***

# %%
#change world_rank:
non_numeric = uni['world_rank'].str.contains('-')
index_drop_list = [i for i, x in enumerate(non_numeric) if x == True]
uni = uni.drop(index=index_drop_list)
uni['world_rank'] = uni['world_rank'].astype(int)

# %% [markdown]
# ## ***IV.2.Define a Label to classify the school score to Excellent, Good, Average, Low or Weak.***

# %%
#Create a field classifications column
def label(element):
    if element >= 85:
        return 'Excellent' #>= 85 is Excellent
    elif element >=70:
        return 'Good' #>= 70 is Good
    elif element >= 55:
        return 'Average' #>= 50 is Average
    elif element >= 40:
        return 'Low' #>= 40 is Low
    elif element < 40:
        return 'Weak' #< 40 is Weak

uni['classification'] = uni['total_score'].apply(label)
value_classification = uni['classification'].value_counts()
value_classification.reset_index()
# Out:
#        index  classification
# 0        Low             554
# 1    Average             403
# 2       Good             157
# 3  Excellent              87

# %% [markdown]
# **And you see there is no weak type in the top University**

# %%
#We draw a plot with shelves containing numbers
plt.figure(figsize=(12,8))
plt.plot(value_classification.index, value_classification)
plt.xlabel('Classification', size=(20))
plt.ylabel('Count',size=(20))
plt.ylim(0,650)
plt.title("Count to Classification",size=(30))
plt.text(-0.1,570,'554',size=(20))
plt.text(3, 95, '87',size=(20))
plt.text(0.9,415, '403',size=(20))
plt.text(1.95, 180, '157',size=(20))
plt.show()

# %% [markdown]
# ## <span style= 'color:#008080'> We can see that it is not easy to want our school to be in Excellent :)) and in 6 years there are only 87 schools in this category🥲<span>
# ## <span style= 'color:#008080'>And most of the schools are Low </span>![image.png](attachment:image.png)

# %% [markdown]
# ## ***IV.3.Create a correlation table for each column on the figure***

# %%
#matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

plt.figure(figsize=(15,8))
sns.heatmap(uni.corr(), annot=True)
plt.title("Correlation Graph", fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Correlation Graph')

# %% [markdown]
# ## ***IV.4.Create Pie Chart show percent each value in Total Score***

# %% [markdown]
# Percentages Score Affect to Total Score

# %%
total_score = ['teaching_rating','inter_outlook_rating', 'research_rating', 'citations_rating', 'industry_income_rating', 'total_score']
def percentages(col):
    div = col/uni['total_score']
    return div * 100

mean_score_percentages = uni[total_score].apply(percentages)
print(mean_score_percentages)
mean_score_percentages.mean()
# Out:
#       teaching_rating  inter_outlook_rating  research_rating  \
# 0          103.746098             75.338189       102.705515
# 1          101.770833             56.875000       102.083333
# 2          102.301255             86.087866        95.606695
# 3          104.241782             31.283139       104.029692
# 4           96.496815             74.628450       101.273885
# ...               ...                   ...              ...
# 1998        62.804878            171.341463        55.894309
# 1999        52.032520            141.260163        36.788618
# 2000        62.729124            113.849287        55.804481
# 2001        62.372188            132.719836        46.830266
# 2002        69.877049            191.393443        68.237705
#
#       citations_rating  industry_income_rating  total_score
# 0           102.809573               35.900104        100.0
# 1           104.062500               87.187500        100.0
# 2           104.497908               91.527197        100.0
# 3           105.196182               68.186638        100.0
# 4           106.050955                     NaN        100.0
# ...                ...                     ...          ...
# 1998        165.650407               70.528455        100.0
# 1999        203.252033               76.626016        100.0
# 2000        178.615071               95.926680        100.0
# 2001        186.094070               59.304703        100.0
# 2002        141.188525               73.155738        100.0
#
# [1201 rows x 6 columns]
# teaching_rating            83.475419
# inter_outlook_rating      102.623524
# research_rating            85.220204
# citations_rating          131.010927
# industry_income_rating     92.912760
# total_score               100.000000
# dtype: float64

# %%
labels = 'teaching_rating','inter_outlook_rating','research_rating','citations_rating','industry_income_rating'
mean_score_in_total_score = [83.4, 102.5, 85.2, 130.9, 93.1]
explode = (0, 0, 0, 0.1, 0)
cols = ['lightcoral', 'cornsilk', 'lightcyan', 'lightpink', 'mediumpurple']

fig1, ax1 = plt.subplots()
ax1.pie(mean_score_in_total_score, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90, colors = cols)
ax1.axis('equal')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('% Score Affects Total Score', fontdict={'fontsize':15},  weight= 'bold')
plt.show()

# %% [markdown]
# ## <span Style= 'color: lightpink'> As you can see, based on 100% of the total score, you can see that the most influential column is Citations_Rating </span>
# ## <span style='color:lightblue'> accounted for 26,4% of the total value </span>
#
# # Conclusion: of the highest total impact score from Citations Rating

# %% [markdown]
# ## ***IV.5.Top 5 University World in each year***

# %%
#Top 5 University World Rank 2011 - 2016
uni.loc[uni['world_rank']<=5]
# Out:
#       world_rank                        university_name  \
# 0              1                     Harvard University
# 1              2     California Institute of Technology
# 2              3  Massachusetts Institute of Technology
# 3              4                    Stanford University
# 4              5                   Princeton University
# 200            1     California Institute of Technology
# 201            2                     Harvard University
# 202            2                    Stanford University
# 203            4                   University of Oxford
# 204            5                   Princeton University
# 602            1     California Institute of Technology
# 603            2                    Stanford University
# 604            2                   University of Oxford
# 605            4                     Harvard University
# 606            5  Massachusetts Institute of Technology
# 1002           1     California Institute of Technology
# 1003           2                     Harvard University
# 1004           2                   University of Oxford
# 1005           4                    Stanford University
# 1006           5  Massachusetts Institute of Technology
# 1402           1     California Institute of Technology
# 1403           2                     Harvard University
# 1404           3                   University of Oxford
# 1405           4                    Stanford University
# 1406           5                University of Cambridge
# 1803           1     California Institute of Technology
# 1804           2                   University of Oxford
# 1805           3                    Stanford University
# 1806           4                University of Cambridge
# 1807           5  Massachusetts Institute of Technology
#
#                        country  teaching_rating  inter_outlook_rating  \
# 0     United States of America             99.7                  72.4
# 1     United States of America             97.7                  54.6
# 2     United States of America             97.8                  82.3
# 3     United States of America             98.3                  29.5
# 4     United States of America             90.9                  70.3
# 200   United States of America             95.7                  56.0
# 201   United States of America             95.8                  67.5
# 202   United States of America             94.8                  57.2
# 203             United Kingdom             89.5                  91.9
# 204   United States of America             91.5                  49.6
# 602   United States of America             96.3                  59.8
# 603   United States of America             95.0                  56.6
# 604             United Kingdom             89.7                  88.7
# 605   United States of America             94.9                  63.7
# 606   United States of America             92.9                  81.6
# 1002  United States of America             94.4                  65.8
# 1003  United States of America             95.3                  66.2
# 1004            United Kingdom             89.0                  90.2
# 1005  United States of America             94.7                  68.0
# 1006  United States of America             92.9                  82.0
# 1402  United States of America             92.2                  67.0
# 1403  United States of America             92.9                  67.6
# 1404            United Kingdom             88.6                  90.7
# 1405  United States of America             91.5                  69.0
# 1406            United Kingdom             89.7                  87.8
# 1803  United States of America             95.6                  64.0
# 1804            United Kingdom             86.5                  94.4
# 1805  United States of America             92.5                  76.3
# 1806            United Kingdom             88.2                  91.5
# 1807  United States of America             89.4                  84.0
#
#       research_rating  citations_rating  industry_income_rating  total_score  \
# 0                98.7              98.8                    34.5         96.1
# 1                98.0              99.9                    83.7         96.0
# 2                91.4              99.9                    87.5         95.6
# 3                98.1              99.2                    64.3         94.3
# 4                95.4              99.9                     NaN         94.2
# 200              98.2              99.9                    97.0         94.8
# 201              97.4              99.8                    35.9         93.9
# 202              98.9              99.8                    63.8         93.9
# 203              96.6              97.9                    62.1         93.6
# 204              99.1             100.0                    81.0         92.9
# 602              99.4              99.7                    95.6         95.5
# 603              98.8              99.3                    62.4         93.7
# 604              98.1              95.6                    79.8         93.7
# 605              98.6              99.2                    39.9         93.6
# 606              89.2              99.9                    92.9         93.1
# 1002             98.2              99.8                    91.2         94.9
# 1003             98.5              99.1                    40.6         93.9
# 1004             98.5              95.4                    90.3         93.9
# 1005             96.8              99.1                    61.3         93.8
# 1006             89.0             100.0                    94.3         93.0
# 1402             98.1              99.7                    89.1         94.3
# 1403             98.6              98.9                    44.0         93.3
# 1404             97.7              95.5                    72.9         93.2
# 1405             96.7              99.1                    63.1         92.9
# 1406             95.6              95.2                    51.1         92.0
# 1803             97.6              99.8                    97.8         95.2
# 1804             98.9              98.8                    73.1         94.2
# 1805             96.2              99.9                    63.3         93.9
# 1806             96.7              97.0                    55.0         92.8
# 1807             88.6              99.7                    95.4         92.0
#
#       num_students  student_staff_ratio  %_inter_students  %_female_students  \
# 0          20152.0                  8.9              25.0                NaN
# 1           2243.0                  6.9              27.0               33.0
# 2          11074.0                  9.0              33.0               37.0
# 3          15596.0                  7.8              22.0               42.0
# 4           7929.0                  8.4              27.0               45.0
# 200         2243.0                  6.9              27.0               33.0
# 201        20152.0                  8.9              25.0                NaN
# 202        15596.0                  7.8              22.0               42.0
# 203        19919.0                 11.6              34.0               46.0
# 204         7929.0                  8.4              27.0               45.0
# 602         2243.0                  6.9              27.0               33.0
# 603        15596.0                  7.8              22.0               42.0
# 604        19919.0                 11.6              34.0               46.0
# 605        20152.0                  8.9              25.0                NaN
# 606        11074.0                  9.0              33.0               37.0
# 1002        2243.0                  6.9              27.0               33.0
# 1003       20152.0                  8.9              25.0                NaN
# 1004       19919.0                 11.6              34.0               46.0
# 1005       15596.0                  7.8              22.0               42.0
# 1006       11074.0                  9.0              33.0               37.0
# 1402        2243.0                  6.9              27.0               33.0
# 1403       20152.0                  8.9              25.0                NaN
# 1404       19919.0                 11.6              34.0               46.0
# 1405       15596.0                  7.8              22.0               42.0
# 1406       18812.0                 11.8              34.0               46.0
# 1803        2243.0                  6.9              27.0               33.0
# 1804       19919.0                 11.6              34.0               46.0
# 1805       15596.0                  7.8              22.0               42.0
# 1806       18812.0                 11.8              34.0               46.0
# 1807       11074.0                  9.0              33.0               37.0
#
#       year classification
# 0     2011      Excellent
# 1     2011      Excellent
# 2     2011      Excellent
# 3     2011      Excellent
# 4     2011      Excellent
# 200   2012      Excellent
# 201   2012      Excellent
# 202   2012      Excellent
# 203   2012      Excellent
# 204   2012      Excellent
# 602   2013      Excellent
# 603   2013      Excellent
# 604   2013      Excellent
# 605   2013      Excellent
# 606   2013      Excellent
# 1002  2014      Excellent
# 1003  2014      Excellent
# 1004  2014      Excellent
# 1005  2014      Excellent
# 1006  2014      Excellent
# 1402  2015      Excellent
# 1403  2015      Excellent
# 1404  2015      Excellent
# 1405  2015      Excellent
# 1406  2015      Excellent
# 1803  2016      Excellent
# 1804  2016      Excellent
# 1805  2016      Excellent
# 1806  2016      Excellent
# 1807  2016      Excellent

# %% [markdown]
# **Chart**

# %%
years = [2011, 2012, 2013, 2014, 2015, 2016]
total_score = ['university_name', 'teaching_rating','inter_outlook_rating', 'research_rating', 'citations_rating', 'industry_income_rating', 'total_score']
#Use for in use for in to create a year-by-year variable for the title
for year in years:
  top_5_world_rank = uni.loc[uni['world_rank']<=5]
  top_5_world_rank = top_5_world_rank.loc[top_5_world_rank['year']==year]
  top_5_world_rank = top_5_world_rank.drop(['country' ,'world_rank','num_students','%_inter_students','%_female_students','student_staff_ratio'], axis = 1)
  top_5_world_rank_grouped = top_5_world_rank.groupby('year')[total_score]
  top_5_world_rank_grouped.plot(figsize=(15,8), x= 'university_name', kind='bar', title ='Overall Score University World in {}'.format(year) , ylim=(0,150))
  plt.xlabel('University Name', size=(20))
  plt.ylabel('Score', size=(20))
  plt.xticks(rotation=45)

# %% [markdown]
# ## <span style= 'color:#ffb90f'> According to the statistics and maps, we can see that the Top 1 in 2011 belongs to Harvard University</span>
# ## <span style= 'color:#ffb90f'> But from 2012 to 2016, the Top 1 belonged to California Institute Technology University </span>
# # <span style= 'color:#b22222'> Congratulations California Institute Technology University🎉🎉🎉!!!!</span>

# %% [markdown]
# ## ***IV.6.Top 5 Universities's ranking chart per year***

# %% [markdown]
# Describe top 5 work rank data

# %%
top_5_world_rank.describe()
# Out:
#        teaching_rating  inter_outlook_rating  research_rating  \
# count         5.000000               5.00000         5.000000
# mean         90.440000              82.04000        95.600000
# std           3.622568              12.29321         4.045368
# min          86.500000              64.00000        88.600000
# 25%          88.200000              76.30000        96.200000
# 50%          89.400000              84.00000        96.700000
# 75%          92.500000              91.50000        97.600000
# max          95.600000              94.40000        98.900000
#
#        citations_rating  industry_income_rating  total_score    year
# count          5.000000                5.000000     5.000000     5.0
# mean          99.040000               76.920000    93.620000  2016.0
# std            1.221884               19.092328     1.245793     0.0
# min           97.000000               55.000000    92.000000  2016.0
# 25%           98.800000               63.300000    92.800000  2016.0
# 50%           99.700000               73.100000    93.900000  2016.0
# 75%           99.800000               95.400000    94.200000  2016.0
# max           99.900000               97.800000    95.200000  2016.0

# %%
top_uni = ['Harvard University', 'California Institute of Technology', 'Massachusetts Institute of Technology', 'Stanford University', 'University of Oxford']

topunis_df = uni[uni['university_name'].isin(top_uni)][['year','university_name','world_rank']].reset_index(drop=True)

fig = plt.figure(figsize=(15,15), dpi=100)

for uni_name, i in zip(top_uni, range(1, 7)):
    new_df = topunis_df[topunis_df['university_name'] == uni_name]
    ax = fig.add_subplot(3, 2, i)
    ax.plot(new_df['year'], new_df['world_rank'], color='#003f5c', linewidth=1.5)
    plt.gca().invert_yaxis()
    ax.set_title(uni_name, color='#ff4800')
    
fig.subplots_adjust(wspace=0.2, hspace=0.6, top=0.92)
fig.suptitle('Ranking of top 5 universities from 2011 to 2016', fontsize=15, color = '#ff4800');

# %% [markdown]
# ## ***IV.7.By country***

# %% [markdown]
# ### Define country using Sub Data

# %%
#Có 32 quốc gia và tổng cộng 261 trường lọt vào top 200 từ năm 2011 đến 2016
country_grouped = uni.groupby('country').agg({'university_name': 'nunique'}).sort_values(by='university_name',ascending=0)
print(country_grouped)
# Out:
#                           university_name
# country
# United States of America               86
# United Kingdom                         35
# Germany                                22
# Netherlands                            12
# Canada                                 12
# France                                  8
# Australia                               8
# China                                   7
# Sweden                                  7
# Switzerland                             7
# Hong Kong                               6
# South Korea                             5
# Japan                                   5
# Belgium                                 5
# Turkey                                  5
# Taiwan                                  4
# Denmark                                 3
# Israel                                  3
# Italy                                   3
# Spain                                   3
# Singapore                               2
# Republic of Ireland                     2
# Norway                                  2
# Austria                                 2
# Egypt                                   1
# South Africa                            1
# Russian Federation                      1
# Finland                                 1
# New Zealand                             1
# Brazil                                  1
# Luxembourg                              1

# %% [markdown]
# ## <span style ='color:#CD853F'> Did you see that the value by Country is very large?</span>
#  ## <span style ='color:#CD853F'> Should I created a Dataset to group it by Region! </span>

# %% [markdown]
# Created a Dataset to group it by Region!

# %% [markdown]
# ### There are 32 countries and a total of 261 schools in the top 200 from 2011 to 2016

# %%
region_dict = pd.read_excel(FILE_URL_SUB)
region_dict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Region   32 non-null     object
#  1   Country  32 non-null     object
# dtypes: object(2)
# memory usage: 640.0+ bytes

# %%
#Apply map_regions, it's dataset create by me, because we will filter Countries to Regions

def map_region(name):
    for i, country in enumerate(region_dict['Country']):
        if name == country:
            return region_dict.loc[i, 'Region']
        else:
            pass

uni['Region'] = uni['country'].apply(map_region)

# %%
#Total Count University in Regions
regions = uni[['Region','university_name']]
regions_count = regions.drop_duplicates()['Region'].value_counts()
print(regions_count)
# Out:
# Northern America     98
# Western Europe       69
# Central Europe       31
# Western Asian        27
# Northern Europe      13
# Australia             9
# Eastern Asian         9
# Southeastern Asia     2
# South Africa          1
# South America         1
# Eastern Europe        1
# Name: Region, dtype: int64

# %%
plt.figure(figsize=(15,7))
plt.barh(regions_count.index, regions_count,color = ['#2ee8bb'],align='center')
plt.title('University in Regions')
plt.xlabel('Count', size=(15))
plt.ylabel('Regions', size=(15))
plt.show()
#Đếm số trường có trong khu vực Regions

# %%
total_score_countries = {}
countries = uni['country'].unique() 
for r in countries:
    country_group = uni[uni['country'] == r] 
    country_mean = country_group['total_score'].mean()
    total_score_countries[r] = country_mean
total_score_countries
# Out:
# {'United States of America': 64.50800915331808,
#  'United Kingdom': 58.994086021505375,
#  'Switzerland': 61.02439024390245,
#  'Canada': 60.98125000000001,
#  'Hong Kong': 60.21363636363637,
#  'Japan': 59.47407407407406,
#  'South Korea': 58.821739130434786,
#  'Singapore': 65.60000000000001,
#  'Australia': 60.120000000000005,
#  'China': 61.33888888888888,
#  'France': 55.00555555555556,
#  'Sweden': 56.584375,
#  'Germany': 54.73417721518989,
#  'Republic of Ireland': 51.79090909090908,
#  'Finland': 56.03333333333333,
#  'Taiwan': 50.97777777777779,
#  'South Africa': 54.05000000000001,
#  'Turkey': 50.01428571428571,
#  'Netherlands': 55.356521739130436,
#  'Belgium': 54.21363636363635,
#  'Denmark': 51.555555555555564,
#  'Norway': 48.04285714285715,
#  'Spain': 49.6125,
#  'New Zealand': 48.633333333333326,
#  'Egypt': 51.6,
#  'Austria': 48.47142857142857,
#  'Israel': 48.077777777777776,
#  'Brazil': 47.3,
#  'Italy': 54.574999999999996,
#  'Russian Federation': 48.95,
#  'Luxembourg': 49.4}

# %% [markdown]
# ###Total Count University in Country

# %% [markdown]
# ###***By region***

# %%
mean_total_score_regions = uni.groupby('Region').agg({'total_score': 'mean'})
print(mean_total_score_regions)
# Out:
#                    total_score
# Region
# Australia            58.768627
# Central Europe       56.419685
# Eastern Asian        49.082353
# Eastern Europe       48.950000
# Northern America     64.158969
# Northern Europe      54.146032
# South Africa         54.050000
# South America        47.300000
# Southeastern Asia    65.600000
# Western Asian        59.053535
# Western Europe       56.972404

# %%
#Create barh chart about Mean Total Score in Regions
plt.figure(figsize=(12,8))
plt.barh(mean_total_score_regions.index, mean_total_score_regions['total_score'],color='#5ca904',align='center')
plt.title('Mean Total Score in Regions',size=(30))
plt.xlabel('Score',size=(20))
plt.ylabel('Regions', size=(20))
plt.xlim(0,70)
plt.show()

# %% [markdown]
# ## <span style= 'color:#FF6A6A'> After plotting, we can see that the Southern Asian region has the highest average score </Span>
# ## <span style= 'color:#FF6A6A'> We Asia are too good, right?!</span>

# %% [markdown]
# ## ***IV.8.Female and Male student***

# %%
PFS_grouped = uni.groupby('year')
per_female_grouped = PFS_grouped['%_female_students'].agg(np.mean)
per_male_grouped = 100 - per_female_grouped
per_male_grouped = per_male_grouped.rename(index='%_male_students')
print(per_female_grouped)
print(per_male_grouped)
# Out:
# year
# 2011    49.426966
# 2012    49.849162
# 2013    49.329609
# 2014    49.234637
# 2015    49.142857
# 2016    50.209945
# Name: %_female_students, dtype: float64
# year
# 2011    50.573034
# 2012    50.150838
# 2013    50.670391
# 2014    50.765363
# 2015    50.857143
# 2016    49.790055
# Name: %_male_students, dtype: float64

# %%
# create 100% stacked bar
# prepair data in percentage
df= pd.concat([per_female_grouped, per_male_grouped], axis= 1)
r = [0, 1, 2, 3, 4, 5]
female_bar = list(df['%_female_students'])
male_bar = list(df['%_male_students'])
# plot info
barHeight = 0.85
names = tuple(df.index)
fig, ax = plt.subplots()
# create Female Bars
ax.barh(r, female_bar, color='#ff99ff', edgecolor='white', height=barHeight, label="Female")
# create Male Bars
ax.barh(r, male_bar, left=female_bar, color='#6699ff', edgecolor='white', height=barHeight, label="Male")

# custom x axis
plt.yticks(r, names) # set the name of each Bar
ax.set_xticks([0,25,75,100]) # overwrite the xticks at the bottom
plt.tick_params(bottom=0, left=0) # disable the tick from bottom and left side

for pos in ['top', 'left', 'right', 'bottom']:
    ax.spines[pos].set_visible(0)
 
# add a legend
ax.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)
 
# add a line
ax.axvline(x=50, ls='-', color = 'b', ymin=0.02, ymax=0.95)
ax.text(x=50, y=-1.2, s='50', ha='center')
ax.set_title(label='Percent By Group and Gender')

# show graph
plt.show()

# %% [markdown]
# ## <span style= 'color:#cd5c5c'> And we can see the balance between men and women in modern times! There is no difference and always in balance </span>
# ## <span style= 'color:#cd5c5c'> Conclusion: With a developed and modern society, women also have the right to be talented people, leaders, politicians, and rulers.</span>

# %% [markdown]
# # **V. Conclusion**

# %% [markdown]
# The data shows that universities led the globe from 2011 to 2016, with additional valuable information regarding levels, teaching ratings, inter outlook ratings, research ratings, citations ratings, and industry revenue ratings.
#
# This rating aims to convey prestige about training degrees to students and businesses, so we can find out which colleges we need to follow, in which country has many places for students to study.
#
# There are five colleges that everyone recognizes that are at the top of the globe in these years: Harvard University, California Institute of Technology, Massachusetts Institute of Technology, Stanford University, and Princeton University.
#
# It's entirely from America, which also has the most universities from 2011 to 2016.
